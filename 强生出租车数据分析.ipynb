# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('all.txt', sep='|', header=None)
data.head()
# Out:
#       0  1   2   3  4    5    6   7                    8   \
# 0  10559  A   0   1  2  0.0  0.0   0  2018-04-01 03:37:00
# 1  30049  A   0   1  1  0.0  0.0   0  2018-04-01 03:37:00
# 2  18890  A   0   1  1  0.0  0.0   0  2018-04-01 03:37:00
# 3  18314  A   0   0  0  0.0  0.0   0  2018-04-01 03:37:00
# 4  20883  A   0   0  0  0.0  0.0   0  2018-04-01 03:37:00
#
#                     9           10         11    12     13  14   15
# 0  2018-04-01 03:37:02  121.368262  31.253850  10.0  253.0   8  011
# 1  2018-04-01 03:37:02  121.684538  31.177227   0.0  332.0   8  000
# 2  2018-04-01 03:37:01  121.817557  31.116977   0.0  343.0  10  000
# 3  2018-04-01 03:37:02  121.304983  31.244210   0.0  114.0   8  000
# 4  2018-04-01 03:37:02  121.462240  31.040312   0.0    0.0   8  000

# %%
data.describe()
# Out:
#                  0             2             3             5             6   \
# count  8.524456e+07  8.524456e+07  8.524456e+07  8.524454e+07  8.524454e+07
# mean   1.953958e+04  8.414496e-04  5.502687e-01  4.679884e-02  3.196250e-02
# std    6.016337e+03  2.899554e-02  5.126118e-01  2.112089e-01  1.759003e-01
# min    3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.467900e+04  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    1.888800e+04  0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 75%    2.560900e+04  0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# max    3.201000e+04  1.000000e+00  3.000000e+00  7.000000e+00  2.000000e+00
#
#                  7             10            11            12            13  \
# count  8.524456e+07  8.524456e+07  8.524456e+07  8.524456e+07  8.524456e+07
# mean   1.615852e-02  1.214591e+02  3.122871e+01  1.290241e+01  1.843713e+02
# ...

# %%
data.columns = ['ID','Control','Status1','Service','Lamp','Status2','Status3','Meaningless','Date','GPSDate','Lon','Lat','Velocity','Direction','Satellite','Meaningless']
data.head()
# Out:
#       ID Control  Status1  Service Lamp  Status2  Status3 Meaningless  \
# 0  10559       A        0        1    2      0.0      0.0           0
# 1  30049       A        0        1    1      0.0      0.0           0
# 2  18890       A        0        1    1      0.0      0.0           0
# 3  18314       A        0        0    0      0.0      0.0           0
# 4  20883       A        0        0    0      0.0      0.0           0
#
#                   Date              GPSDate         Lon        Lat  Velocity  \
# 0  2018-04-01 03:37:00  2018-04-01 03:37:02  121.368262  31.253850      10.0
# 1  2018-04-01 03:37:00  2018-04-01 03:37:02  121.684538  31.177227       0.0
# 2  2018-04-01 03:37:00  2018-04-01 03:37:01  121.817557  31.116977       0.0
# 3  2018-04-01 03:37:00  2018-04-01 03:37:02  121.304983  31.244210       0.0
# 4  2018-04-01 03:37:00  2018-04-01 03:37:02  121.462240  31.040312       0.0
#
#    Direction  Satellite Meaningless
# 0      253.0          8         011
# ...

# %%
data_airport = data[(data["Lon"]>=121.772183) & (data["Lon"]<=121.831578) & (data["Lat"]<=31.177560) & (data["Lat"]>=31.105273)]
data_airport.head()
# Out:
#         ID Control  Status1  Service Lamp  Status2  Status3 Meaningless  \
# 2    18890       A        0        1    1      0.0      0.0           0
# 40   22052       A        0        1    1      0.0      0.0           0
# 109  20272       A        0        0    0      0.0      0.0           0
# 197  26760       A        0        1    1      0.0      0.0           0
# 277  28221       A        0        1    1      0.0      0.0           0
#
#                     Date              GPSDate         Lon        Lat  \
# 2    2018-04-01 03:37:00  2018-04-01 03:37:01  121.817557  31.116977
# 40   2018-04-01 03:37:00  2018-04-01 03:37:02  121.804668  31.150907
# 109  2018-04-01 03:37:00  2018-04-01 03:37:02  121.818620  31.118170
# 197  2018-04-01 03:37:00  2018-04-01 03:37:02  121.817468  31.116957
# 277  2018-04-01 03:37:00  2018-04-01 03:37:02  121.818425  31.118010
#
#      Velocity  Direction  Satellite Meaningless
# 2         0.0      343.0         10         000
# ...

# %%
data_airport.dtypes
# Out:
# ID               int64
# Control         object
# Status1          int64
# Service          int64
# Lamp            object
# Status2        float64
# Status3        float64
# Meaningless      int64
# Date            object
# GPSDate         object
# Lon            float64
# Lat            float64
# Velocity       float64
# Direction      float64
# Satellite        int64
# Meaningless     object
# dtype: object

# %%
data_airport["Date"] = pd.to_datetime(data_airport["Date"])
data_airport["GPSDate"] = pd.to_datetime(data_airport["GPSDate"])
data_airport.dtypes
# Out:
# /Users/y1.han/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/y1.han/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ID                      int64
# Control                object
# Status1                 int64
# Service                 int64
# Lamp                   object
# Status2               float64
# ...

# %%
data_airport.head()
# Out:
#         ID Control  Status1  Service Lamp  Status2  Status3 Meaningless  \
# 2    18890       A        0        1    1      0.0      0.0           0
# 40   22052       A        0        1    1      0.0      0.0           0
# 109  20272       A        0        0    0      0.0      0.0           0
# 197  26760       A        0        1    1      0.0      0.0           0
# 277  28221       A        0        1    1      0.0      0.0           0
#
#                    Date             GPSDate         Lon        Lat  Velocity  \
# 2   2018-04-01 03:37:00 2018-04-01 03:37:01  121.817557  31.116977       0.0
# 40  2018-04-01 03:37:00 2018-04-01 03:37:02  121.804668  31.150907       0.0
# 109 2018-04-01 03:37:00 2018-04-01 03:37:02  121.818620  31.118170       0.0
# 197 2018-04-01 03:37:00 2018-04-01 03:37:02  121.817468  31.116957       0.0
# 277 2018-04-01 03:37:00 2018-04-01 03:37:02  121.818425  31.118010       0.0
#
#      Direction  Satellite Meaningless
# ...

# %%
data_test = data_airport
data_test["hour"] = data_test.GPSDate.dt.hour
data_test.tail()
# Out:
# /Users/y1.han/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              ID Control  Status1  Service Lamp  Status2  Status3 Meaningless  \
# 85244403  14580       A        0        0    0      0.0      0.0           0
# 85244405  26147       A        0        1    1      0.0      0.0           0
# 85244406  26870       A        0        1    1      0.0      0.0           0
# 85244491  26684       A        0        1    1      0.0      0.0           0
# 85244552  10218       A        0        1    1      0.0      0.0           0
#
#                         Date             GPSDate         Lon        Lat  \
# ...

# %%
hour_taxi = data_test.groupby(by="hour").ID.nunique()
hour_taxi
# Out:
# hour
# 0     377
# 1     235
# 2     188
# 3     166
# 4     202
# 5     380
# 6     502
# 7     497
# 8     517
# 9     595
# 10    647
# 11    623
# 12    600
# 13    683
# 14    766
# 15    809
# 16    810
# 17    818
# 18    816
# 19    885
# 20    845
# 21    779
# 22    592
# 23    479
# Name: ID, dtype: int64

# %%
hour_taxi.plot.bar()

# %%
data_test.groupby(by="hour").Service.mean()
# Out:
# hour
# 0     0.939764
# 1     0.938850
# 2     0.952458
# 3     0.927702
# 4     0.892125
# 5     0.824813
# 6     0.862391
# 7     0.897374
# 8     0.911712
# 9     0.904055
# 10    0.919252
# 11    0.932387
# 12    0.946461
# 13    0.940804
# 14    0.935774
# 15    0.931906
# 16    0.944219
# 17    0.934010
# 18    0.944671
# 19    0.936650
# 20    0.944669
# 21    0.939040
# 22    0.939647
# 23    0.930146
# Name: Service, dtype: float64

# %%
data_test_whole = data
data_test_whole["Date"] = pd.to_datetime(data_test_whole["Date"])
data_test_whole["GPSDate"] = pd.to_datetime(data_test_whole["GPSDate"])
data_test_whole["hour"] = data_test_whole.GPSDate.dt.hour
data_test_whole.groupby(by="hour").Service.mean()
# Out:
# hour
# 0     0.546278
# 1     0.522299
# 2     0.486402
# 3     0.457648
# 4     0.452833
# 5     0.472072
# 6     0.542962
# 7     0.605126
# 8     0.586766
# 9     0.591026
# 10    0.590096
# 11    0.600102
# 12    0.577138
# 13    0.552914
# 14    0.530091
# 15    0.537014
# 16    0.541425
# 17    0.548787
# 18    0.586436
# 19    0.587970
# 20    0.556594
# 21    0.564254
# 22    0.583529
# 23    0.573677
# Name: Service, dtype: float64

# %%
data_test.groupby(by="ID").Service.mean()
# Out:
# ID
# 255      1.000000
# 9009     0.500000
# 9024     0.000000
# 9040     0.702128
# 9059     0.406250
#            ...
# 30250    0.927821
# 31003    0.946588
# 31005    0.676692
# 32007    0.957746
# 32010    0.333333
# Name: Service, Length: 3064, dtype: float64

# %%
hour_taxi = data_test[data_test['Service'] == 1].groupby(by="hour").ID.nunique()
hour_taxi
# Out:
# hour
# 0     354
# 1     219
# 2     182
# 3     158
# 4     181
# 5     336
# 6     458
# 7     461
# 8     478
# 9     558
# 10    603
# 11    582
# 12    571
# 13    653
# 14    731
# 15    774
# 16    777
# 17    768
# 18    781
# 19    842
# 20    799
# 21    743
# 22    561
# 23    457
# Name: ID, dtype: int64

# %%
hour_taxi.plot.bar()

# %%
testing_all = data_test_whole.groupby(by="ID").Velocity.sum()*3.6

# %%
testing_all.hist(grid=False)

# %%
airport_taxi_id = data_airport["ID"].unique()
airport_taxi_id
# Out:
# array([18890, 22052, 20272, ..., 10975, 21274, 17774])

# %%
airport_taxi_whole_city = data_test_whole[data_test_whole["ID"].isin(airport_taxi_id)]
airport_taxi_whole_city.head()
# Out:
#        ID Control  Status1  Service Lamp  Status2  Status3 Meaningless  \
# 1   30049       A        0        1    1      0.0      0.0           0
# 2   18890       A        0        1    1      0.0      0.0           0
# 6   21156       A        0        1    5      0.0      0.0           0
# 12  17997       A        0        0    0      0.0      0.0           0
# 14  16239       A        0        0    0      0.0      0.0           0
#
#                   Date             GPSDate         Lon        Lat  Velocity  \
# 1  2018-04-01 03:37:00 2018-04-01 03:37:02  121.684538  31.177227       0.0
# 2  2018-04-01 03:37:00 2018-04-01 03:37:01  121.817557  31.116977       0.0
# 6  2018-04-01 03:37:00 2018-04-01 03:37:02  121.773662  31.028670       0.0
# 12 2018-04-01 03:37:00 2018-04-01 03:37:02  121.482023  31.169208       0.0
# 14 2018-04-01 03:37:00 2018-04-01 03:37:02  121.623530  31.430895       0.0
#
#     Direction  Satellite Meaningless  hour
# ...

# %%
testing = airport_taxi_whole_city.groupby(by="ID").Velocity.sum()*3.6

# %%
testing.hist(grid=False)

# %%
np.mean(data_test_whole.groupby(by="ID").Velocity.sum()*3.6)
# Out:
# 331671.7607605962

# %%
np.mean(airport_taxi_whole_city.groupby(by="ID").Velocity.sum()*3.6)
# Out:
# 392887.42625326355

# %%
sns.distplot(testing, bins=10)

# %%
sns.distplot(testing_all, bins=10)

# %%
data[data["Velocity"] != 0]["Velocity"].mean()
# Out:
# 31.79413181883863

# %%
pd.DataFrame(hour_taxi)
# Out:
#        ID
# hour
# 0     354
# 1     219
# 2     182
# 3     158
# 4     181
# 5     336
# 6     458
# 7     461
# 8     478
# 9     558
# 10    603
# 11    582
# 12    571
# 13    653
# 14    731
# 15    774
# 16    777
# 17    768
# 18    781
# 19    842
# 20    799
# 21    743
# 22    561
# 23    457
